# %%
# create books dictionary
books = {'亞瑟王' : None, 
         '風聲' : None,
         '心之谷' : None}

# run for 100 times
for i in range(1, 100):
    
    msg = input('輸入訊息：')
    current_user_id = '123abc'
    
    # implement reservation
    if msg == '想看書本種類':
        book_list = []
        for book, user_id in books.items():
            if user_id is None:
                book_list.append(book)
                ##1.將遊戲加到game_list裡面
                
        book_text = '尚可預約書本：\n'
        for book in book_list:
            book_text = book_text + book + '\n'
            ##2.將所有尚可預約的遊戲加到game_text裡面
            
        print(book_text)
    elif msg[0:3] == '想預約':
        book_name = msg[3:]
        found = False
        for book, user_id in books.items():
            if book == book_name:
                found = True
                if user_id is None:
                    books[book_name] = current_user_id
                    
                    ##3.將想要預約的遊戲在字典裡對應的value改成user_id
                    ##  例如，想要預約小瓦隆，請將字典games改成如下
                    '''
                    books = {'亞瑟王' : 123abc, 
                             '風聲' : None,
                             '心之谷' : None}
                    '''
                    
                    print('已為您預約完成：', book)
                else:
                    print('此書本已被預約！抱歉')
        if found == False:
            print('並沒有此款書本')
    elif msg == '想取消預約':
        for book, user_id in books.items():
            if user_id == current_user_id:
                books[book] = None
                
                #4.將遊戲對應的valule改回None表示遊戲取消預約
                #  例如將小瓦隆取消預約，它在字典對應的value應改為None
                '''
                
                games = {'亞瑟王' : None, 
                         '風聲' : None,
                         '心之谷' : None}
                    
                '''
                print('已為您取消預約')
    elif msg == '結束':
        break
    else:
        print('您好！請問需要什麼樣的服務？')
    print('------------------')
# Out:
# 輸入訊息：123abc
# 您好！請問需要什麼樣的服務？
# ------------------
# 輸入訊息：想看書本種類
# 尚可預約書本：
# 亞瑟王
# 風聲
# 心之谷
#
# ------------------
# 輸入訊息：想預約風聲
# 已為您預約完成： 風聲
# ------------------
# 輸入訊息：想看書本種類
# 尚可預約書本：
# 亞瑟王
# 心之谷
#
# ------------------
# 輸入訊息：想預約風聲
# 此書本已被預約！抱歉
# ------------------
# 輸入訊息：想看書本種類
# 尚可預約書本：
# 亞瑟王
# 心之谷
#
# ------------------
# 輸入訊息：想預約 魔山
# 並沒有此款書本
# ------------------
# 輸入訊息：想看書本種類
# 尚可預約書本：
# 亞瑟王
# 心之谷
#
# ------------------
# 輸入訊息：想取消預約風聲
# 您好！請問需要什麼樣的服務？
# ------------------
# 輸入訊息：想取消預約風聲
# 您好！請問需要什麼樣的服務？
# ------------------
# 輸入訊息：想看書本種類
# 尚可預約書本：
# 亞瑟王
# 心之谷
#
# ------------------
# 輸入訊息：想取消預約風聲
# 您好！請問需要什麼樣的服務？
# ------------------
# 輸入訊息：想取消預約風聲
# 您好！請問需要什麼樣的服務？
# ------------------
